# %% [markdown]
# VIX Home Credit_Rakamin Academy
# Batch June 2023

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',150)

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 1.4.2
# 1.21.5

# %% [markdown]
# # Data Manipulation & Join Dataset

# %% [markdown]
# ## Data train.csv

# %% [markdown]
# ### Load Data

# %%
# Load/Extract every table

df_train = pd.read_csv('dataset_vixhomecredit/application_train.csv')
print('df_train', df_train.shape)
# Out:
# df_train (307511, 122)

# %%
c = df_train.select_dtypes(include='int64').columns
d = df_train.select_dtypes(include='float64').columns
df_train[c] = df_train[c].astype('int32')
df_train[d] = df_train[d].astype('float32')

# %%
df_train.isna().sum()
# Out:
# SK_ID_CURR                           0
# TARGET                               0
# NAME_CONTRACT_TYPE                   0
# CODE_GENDER                          0
# FLAG_OWN_CAR                         0
# FLAG_OWN_REALTY                      0
# CNT_CHILDREN                         0
# AMT_INCOME_TOTAL                     0
# AMT_CREDIT                           0
# AMT_ANNUITY                         12
# AMT_GOODS_PRICE                    278
# NAME_TYPE_SUITE                   1292
# NAME_INCOME_TYPE                     0
# NAME_EDUCATION_TYPE                  0
# NAME_FAMILY_STATUS                   0
# NAME_HOUSING_TYPE                    0
# REGION_POPULATION_RELATIVE           0
# DAYS_BIRTH                           0
# DAYS_EMPLOYED                        0
# DAYS_REGISTRATION                    0
# DAYS_ID_PUBLISH                      0
# OWN_CAR_AGE                     202929
# FLAG_MOBIL                           0
# FLAG_EMP_PHONE                       0
# ...

# %%
df_train.isna().mean()
# Out:
# SK_ID_CURR                     0.00
# TARGET                         0.00
# NAME_CONTRACT_TYPE             0.00
# CODE_GENDER                    0.00
# FLAG_OWN_CAR                   0.00
# FLAG_OWN_REALTY                0.00
# CNT_CHILDREN                   0.00
# AMT_INCOME_TOTAL               0.00
# AMT_CREDIT                     0.00
# AMT_ANNUITY                    0.00
# AMT_GOODS_PRICE                0.00
# NAME_TYPE_SUITE                0.00
# NAME_INCOME_TYPE               0.00
# NAME_EDUCATION_TYPE            0.00
# NAME_FAMILY_STATUS             0.00
# NAME_HOUSING_TYPE              0.00
# REGION_POPULATION_RELATIVE     0.00
# DAYS_BIRTH                     0.00
# DAYS_EMPLOYED                  0.00
# DAYS_REGISTRATION              0.00
# DAYS_ID_PUBLISH                0.00
# OWN_CAR_AGE                    0.66
# FLAG_MOBIL                     0.00
# FLAG_EMP_PHONE                 0.00
# FLAG_WORK_PHONE                0.00
# FLAG_CONT_MOBILE               0.00
# ...

# %% [markdown]
# ### Manipulation Data

# %%
# Data Train

df_train2 = df_train.copy()

# Imputation Missing Value
df_train2['OWN_CAR_AGE'] = df_train['OWN_CAR_AGE'].fillna(0)
df_train2['OCCUPATION_TYPE'] = df_train['OCCUPATION_TYPE'].fillna('Other')

# Drop not relevant column
drop_col = ['EXT_SOURCE_1','EXT_SOURCE_2','EXT_SOURCE_3','APARTMENTS_AVG','BASEMENTAREA_AVG','YEARS_BEGINEXPLUATATION_AVG',
               'YEARS_BUILD_AVG','COMMONAREA_AVG','ELEVATORS_AVG','ENTRANCES_AVG','FLOORSMAX_AVG','FLOORSMIN_AVG','LANDAREA_AVG',
               'LIVINGAPARTMENTS_AVG','LIVINGAREA_AVG','NONLIVINGAPARTMENTS_AVG','NONLIVINGAREA_AVG','APARTMENTS_MODE',
               'BASEMENTAREA_MODE','YEARS_BEGINEXPLUATATION_MODE','YEARS_BUILD_MODE','COMMONAREA_MODE','ELEVATORS_MODE',
               'ENTRANCES_MODE','FLOORSMAX_MODE','FLOORSMIN_MODE','LANDAREA_MODE','LIVINGAPARTMENTS_MODE','LIVINGAREA_MODE',
               'NONLIVINGAPARTMENTS_MODE','NONLIVINGAREA_MODE','APARTMENTS_MEDI','BASEMENTAREA_MEDI','YEARS_BEGINEXPLUATATION_MEDI',
               'YEARS_BUILD_MEDI','COMMONAREA_MEDI','ELEVATORS_MEDI','ENTRANCES_MEDI','FLOORSMAX_MEDI','FLOORSMIN_MEDI',
               'LANDAREA_MEDI','LIVINGAPARTMENTS_MEDI','LIVINGAREA_MEDI','NONLIVINGAPARTMENTS_MEDI','NONLIVINGAREA_MEDI',
               'FONDKAPREMONT_MODE','HOUSETYPE_MODE','TOTALAREA_MODE','WALLSMATERIAL_MODE','EMERGENCYSTATE_MODE',
               'AMT_REQ_CREDIT_BUREAU_HOUR','AMT_REQ_CREDIT_BUREAU_DAY','AMT_REQ_CREDIT_BUREAU_WEEK','AMT_REQ_CREDIT_BUREAU_MON',
               'AMT_REQ_CREDIT_BUREAU_QRT','AMT_REQ_CREDIT_BUREAU_YEAR']
df_train2 = df_train2.drop(drop_col, axis=1)
df_train3 = df_train2.dropna(axis=0)
print('Jumlah baris dan kolom:', df_train3.shape)
print('Jumlah missing value:', df_train3.isna().any().sum())
# Out:
# Jumlah baris dan kolom: (305185, 66)
# Jumlah missing value: 0

# %% [markdown]
# ## Dataset bureau.csv

# %% [markdown]
# ### Load Data

# %%
df_bureau = pd.read_csv('dataset_vixhomecredit/bureau.csv')
print(df_bureau.shape)
print(df_bureau.info())
c1 = df_bureau.select_dtypes(include='int64').columns
c2 = df_bureau.select_dtypes(include='float64').columns
df_bureau[c1] = df_bureau[c1].astype('int32')
df_bureau[c2] = df_bureau[c2].astype('float32')
print(df_bureau.isna().sum())
print('\n')
print(df_bureau.isna().mean())
df_bureau.head(5)
# Out:
# (1716428, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716428 entries, 0 to 1716427
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   SK_ID_CURR              int64
#  1   SK_ID_BUREAU            int64
#  2   CREDIT_ACTIVE           object
#  3   CREDIT_CURRENCY         object
#  4   DAYS_CREDIT             int64
#  5   CREDIT_DAY_OVERDUE      int64
#  6   DAYS_CREDIT_ENDDATE     float64
#  7   DAYS_ENDDATE_FACT       float64
#  8   AMT_CREDIT_MAX_OVERDUE  float64
#  9   CNT_CREDIT_PROLONG      int64
#  10  AMT_CREDIT_SUM          float64
#  11  AMT_CREDIT_SUM_DEBT     float64
#  12  AMT_CREDIT_SUM_LIMIT    float64
#  13  AMT_CREDIT_SUM_OVERDUE  float64
#  14  CREDIT_TYPE             object
#  15  DAYS_CREDIT_UPDATE      int64
#  16  AMT_ANNUITY             float64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 222.6+ MB
# None
# SK_ID_CURR                      0
# ...

# %% [markdown]
# ### Manipulation Data

# %%
df_bureau2 = df_bureau.copy()
drop_col_bureau = ['DAYS_ENDDATE_FACT','AMT_CREDIT_MAX_OVERDUE','AMT_CREDIT_SUM_DEBT',
                   'AMT_CREDIT_SUM_LIMIT','AMT_ANNUITY']
df_bureau2 = df_bureau2.drop(drop_col_bureau, axis=1)
df_bureau3 = df_bureau2.dropna(axis=0)
print('Jumlah baris dan kolom:', df_bureau3.shape)
print('Jumlah missing value:', df_bureau3.isna().any().sum())
# Out:
# Jumlah baris dan kolom: (1610871, 12)
# Jumlah missing value: 0

# %% [markdown]
# ## Dataset bureau_balance.csv

# %% [markdown]
# ### Load Data

# %%
df_bureau_balance = pd.read_csv('dataset_vixhomecredit/bureau_balance.csv')
print(df_bureau_balance.shape)
print(df_bureau_balance.info())
d1 = df_bureau.select_dtypes(include='int64').columns
df_bureau[d1] = df_bureau[d1].astype('int32')
print(df_bureau_balance.isna().sum())
print('\n')
print(df_bureau_balance.isna().mean())
df_bureau_balance.head(5)
# Out:
# (27299925, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27299925 entries, 0 to 27299924
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   SK_ID_BUREAU    int64
#  1   MONTHS_BALANCE  int64
#  2   STATUS          object
# dtypes: int64(2), object(1)
# memory usage: 624.8+ MB
# None
# SK_ID_BUREAU      0
# MONTHS_BALANCE    0
# STATUS            0
# dtype: int64
#
#
# SK_ID_BUREAU     0.00
# MONTHS_BALANCE   0.00
# STATUS           0.00
# dtype: float64
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %% [markdown]
# ## Dataset POS_CASH_balance.csv

# %% [markdown]
# ### Load Data

# %%
df_poscash = pd.read_csv('dataset_vixhomecredit/POS_CASH_balance.csv')
print(df_poscash.shape)
print(df_poscash.info())
e1 = df_poscash.select_dtypes(include='int64').columns
e2 = df_poscash.select_dtypes(include='float64').columns
df_poscash[e1] = df_poscash[e1].astype('int32')
df_poscash[e2] = df_poscash[e2].astype('float32')
print(df_poscash.isna().sum())
print('\n')
print(df_poscash.isna().mean())
# Out:
# (10001358, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001358 entries, 0 to 10001357
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   SK_ID_PREV             int64
#  1   SK_ID_CURR             int64
#  2   MONTHS_BALANCE         int64
#  3   CNT_INSTALMENT         float64
#  4   CNT_INSTALMENT_FUTURE  float64
#  5   NAME_CONTRACT_STATUS   object
#  6   SK_DPD                 int64
#  7   SK_DPD_DEF             int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 610.4+ MB
# None
# SK_ID_PREV                   0
# SK_ID_CURR                   0
# MONTHS_BALANCE               0
# CNT_INSTALMENT           26071
# CNT_INSTALMENT_FUTURE    26087
# NAME_CONTRACT_STATUS         0
# SK_DPD                       0
# SK_DPD_DEF                   0
# dtype: int64
#
#
# SK_ID_PREV              0.00
# SK_ID_CURR              0.00
# MONTHS_BALANCE          0.00
# CNT_INSTALMENT          0.00
# ...

# %% [markdown]
# ### Manipulation Data

# %%
df_poscash2 = df_poscash.copy()
df_poscash2 = df_poscash2.dropna(axis=0)
print('Jumlah baris dan kolom:', df_poscash2.shape)
print('Jumlah missing value:', df_poscash2.isna().any().sum())
# Out:
# Jumlah baris dan kolom: (9975174, 8)
# Jumlah missing value: 0

# %% [markdown]
# ## Dataset credit_card_balance.csv

# %% [markdown]
# ### Load Data

# %%
df_creditcardbalance = pd.read_csv('dataset_vixhomecredit/credit_card_balance.csv')
print(df_creditcardbalance.shape)
print(df_creditcardbalance.info())
f1 = df_creditcardbalance.select_dtypes(include='int64').columns
f2 = df_creditcardbalance.select_dtypes(include='float64').columns
df_creditcardbalance[f1] = df_creditcardbalance[f1].astype('int32')
df_creditcardbalance[f2] = df_creditcardbalance[f2].astype('float32')
print(df_creditcardbalance.isna().sum())
print('\n')
print(df_creditcardbalance.isna().mean())
df_creditcardbalance.head(5)
# Out:
# (3840312, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3840312 entries, 0 to 3840311
# Data columns (total 23 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   SK_ID_PREV                  int64
#  1   SK_ID_CURR                  int64
#  2   MONTHS_BALANCE              int64
#  3   AMT_BALANCE                 float64
#  4   AMT_CREDIT_LIMIT_ACTUAL     int64
#  5   AMT_DRAWINGS_ATM_CURRENT    float64
#  6   AMT_DRAWINGS_CURRENT        float64
#  7   AMT_DRAWINGS_OTHER_CURRENT  float64
#  8   AMT_DRAWINGS_POS_CURRENT    float64
#  9   AMT_INST_MIN_REGULARITY     float64
#  10  AMT_PAYMENT_CURRENT         float64
#  11  AMT_PAYMENT_TOTAL_CURRENT   float64
#  12  AMT_RECEIVABLE_PRINCIPAL    float64
#  13  AMT_RECIVABLE               float64
#  14  AMT_TOTAL_RECEIVABLE        float64
#  15  CNT_DRAWINGS_ATM_CURRENT    float64
#  16  CNT_DRAWINGS_CURRENT        int64
#  17  CNT_DRAWINGS_OTHER_CURRENT  float64
# ...

# %% [markdown]
# ### Manipulation Data

# %%
df_creditcardbalance2 = df_creditcardbalance.fillna(0)
df_creditcardbalance2.isna().any().sum()
# Out:
# 0

# %% [markdown]
# ## Dataset previous_application.csv

# %% [markdown]
# ### Load Data

# %%
df_previous = pd.read_csv('dataset_vixhomecredit/previous_application.csv')
print(df_previous.shape)
print(df_previous.info())
g1 = df_previous.select_dtypes(include='int64').columns
g2 = df_previous.select_dtypes(include='float64').columns
df_previous[g1] = df_previous[g1].astype('int32')
df_previous[g2] = df_previous[g2].astype('float32')
print(df_previous.isna().sum())
print('\n')
print(df_previous.isna().mean())
df_previous.head(5)
# Out:
# (1670214, 37)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %% [markdown]
# ### Manipulation Data

# %%
drop_col_pre = ['AMT_ANNUITY','AMT_DOWN_PAYMENT','AMT_GOODS_PRICE','RATE_DOWN_PAYMENT','RATE_INTEREST_PRIMARY',
                'RATE_INTEREST_PRIVILEGED','NAME_TYPE_SUITE','CNT_PAYMENT','DAYS_FIRST_DRAWING','DAYS_FIRST_DUE',
                'DAYS_LAST_DUE_1ST_VERSION','DAYS_LAST_DUE','DAYS_TERMINATION','NFLAG_INSURED_ON_APPROVAL']

df_previous2 = df_previous.drop(drop_col_pre, axis=1)
df_previous3 = df_previous2.dropna(axis=0)
print(df_previous3.shape)
print(df_previous3.isna().any().sum())
# Out:
# (1669867, 23)
# 0

# %% [markdown]
# ## Dataset installments_payments.csv

# %% [markdown]
# ### Load Data

# %%
df_installmen = pd.read_csv('dataset_vixhomecredit/installments_payments.csv')
print(df_installmen.shape)
print(df_installmen.info())
h1 = df_installmen.select_dtypes(include='int64').columns
h2 = df_installmen.select_dtypes(include='float64').columns
df_installmen[h1] = df_installmen[h1].astype('int32')
df_installmen[h2] = df_installmen[h2].astype('float32')
print(df_installmen.isna().sum())
print('\n')
print(df_installmen.isna().mean())
# Out:
# (13605401, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13605401 entries, 0 to 13605400
# Data columns (total 8 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   SK_ID_PREV              int64
#  1   SK_ID_CURR              int64
#  2   NUM_INSTALMENT_VERSION  float64
#  3   NUM_INSTALMENT_NUMBER   int64
#  4   DAYS_INSTALMENT         float64
#  5   DAYS_ENTRY_PAYMENT      float64
#  6   AMT_INSTALMENT          float64
#  7   AMT_PAYMENT             float64
# dtypes: float64(5), int64(3)
# memory usage: 830.4 MB
# None
# SK_ID_PREV                   0
# SK_ID_CURR                   0
# NUM_INSTALMENT_VERSION       0
# NUM_INSTALMENT_NUMBER        0
# DAYS_INSTALMENT              0
# DAYS_ENTRY_PAYMENT        2905
# AMT_INSTALMENT               0
# AMT_PAYMENT               2905
# dtype: int64
#
#
# SK_ID_PREV               0.00
# SK_ID_CURR               0.00
# NUM_INSTALMENT_VERSION   0.00
# NUM_INSTALMENT_NUMBER    0.00
# ...

# %% [markdown]
# ### Manipulation Data

# %%
df_installmen2 = df_installmen.dropna(axis=0)
print(df_installmen2.shape)
print(df_installmen2.isna().any().sum())
# Out:
# (13602496, 8)
# 0

# %% [markdown]
# # Join Dataset

# %%
# df_train3 vs df_bureau3

df_join1 = df_train3.merge(df_bureau3, left_index=True, right_index=True, how='left')
df_join1 = df_join1.rename(columns={'SK_ID_CURR_x':'SK_ID_CURR'})
df_join1 = df_join1.dropna(axis=0)
print(df_join1.isna().any().sum())
df_join1 = df_join1.drop(['SK_ID_CURR_y','CREDIT_CURRENCY'], axis=1)
print(df_join1.shape)
# Out:
# 0
# (285949, 76)

# %%
# df_join1 vs df_poscash2

df_join2 = df_join1.merge(df_poscash2['SK_DPD'], how='left', left_index=True, right_index=True)
print(df_join2.shape)
df_join2=df_join2.dropna(axis=0)
df_join2.isna().any().sum()
# Out:
# (285949, 77)
# 0

# %%
# df_join2 vs df_creditcardbalance2

df_join3 = df_join2.merge(df_creditcardbalance2, how='left', left_index=True, right_index=True)
print(df_join3.shape)
df_join3.isna().any().sum()
# Out:
# (285446, 100)
# 0

# %%
# df_join3 vs df_installmen2

df_join4 = df_join3.merge(df_installmen2, how='left', left_index=True, right_index=True)
print(df_join4.shape)
print(df_join4.isna().any().sum())
# Out:
# (285446, 108)
# 0

# %%
df_join4 = df_join4.drop(['DEF_30_CNT_SOCIAL_CIRCLE','DEF_60_CNT_SOCIAL_CIRCLE','HOUR_APPR_PROCESS_START','DAYS_REGISTRATION','REGION_POPULATION_RELATIVE','DAYS_ID_PUBLISH','CODE_GENDER','SK_ID_CURR_x','OCCUPATION_TYPE','NAME_CONTRACT_STATUS','CREDIT_TYPE','WEEKDAY_APPR_PROCESS_START','ORGANIZATION_TYPE','NAME_FAMILY_STATUS','NAME_HOUSING_TYPE','NAME_EDUCATION_TYPE','NAME_TYPE_SUITE','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV_x','SK_ID_CURR_y','SK_DPD_y','SK_ID_PREV_y','SK_ID_CURR'], axis=1)
df_join4 = df_join4.rename(columns={'SK_DPD_x':'SK_DPD'})
print(df_join4.shape)
df_join4.head()
# Out:
# (285446, 85)
#    TARGET NAME_CONTRACT_TYPE FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       1         Cash loans            N               Y             0
# 1       0         Cash loans            N               N             0
# 2       0    Revolving loans            Y               Y             0
# 4       0         Cash loans            N               Y             0
# 5       0         Cash loans            N               Y             0
#
#    AMT_INCOME_TOTAL   AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0        202,500.00   406,597.50    24,700.50       351,000.00
# 1        270,000.00 1,293,502.50    35,698.50     1,129,500.00
# 2         67,500.00   135,000.00     6,750.00       135,000.00
# 4        121,500.00   513,000.00    21,865.50       513,000.00
# 5         99,000.00   490,495.50    27,517.50       454,500.00
#
#   NAME_INCOME_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  OWN_CAR_AGE  FLAG_MOBIL  \
# ...

# %% [markdown]
# # Prepocition

# %%
df_join4.dtypes
# Out:
# TARGET                           int32
# NAME_CONTRACT_TYPE              object
# FLAG_OWN_CAR                    object
# FLAG_OWN_REALTY                 object
# CNT_CHILDREN                     int32
# AMT_INCOME_TOTAL               float32
# AMT_CREDIT                     float32
# AMT_ANNUITY                    float32
# AMT_GOODS_PRICE                float32
# NAME_INCOME_TYPE                object
# DAYS_BIRTH                       int32
# DAYS_EMPLOYED                    int32
# OWN_CAR_AGE                    float32
# FLAG_MOBIL                       int32
# FLAG_EMP_PHONE                   int32
# FLAG_WORK_PHONE                  int32
# FLAG_CONT_MOBILE                 int32
# FLAG_PHONE                       int32
# FLAG_EMAIL                       int32
# CNT_FAM_MEMBERS                float32
# REGION_RATING_CLIENT             int32
# REGION_RATING_CLIENT_W_CITY      int32
# REG_REGION_NOT_LIVE_REGION       int32
# REG_REGION_NOT_WORK_REGION       int32
# ...

# %% [markdown]
# ## Feature Selection

# %%
y = df_join4['TARGET']
X = df_join4.drop('TARGET', axis=1)
X_cat = X.select_dtypes(include='object')
X_num = X.select_dtypes(include='number')

# %%
from sklearn.preprocessing import StandardScaler
X_num_col = X_num.columns

for i in X_num_col:
    X_num[i] = StandardScaler().fit_transform(X_num[i].values.reshape(len(X_num),1))

# %%
# numeric vs category

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

fs = SelectKBest(score_func=f_classif, k=40)
fs.fit(X_num, y)
cols = fs.get_support(indices=True)
df_selected_features = X_num.iloc[:,cols]
df_selected_features.head()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [8] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0         -0.58              0.14       -0.48        -0.17            -0.51
# 1         -0.58              0.41        1.73         0.59             1.60
# 2         -0.58             -0.41       -1.16        -1.41            -1.09
# 4         -0.58             -0.19       -0.22        -0.36            -0.07
# 5         -0.58             -0.29       -0.27         0.03            -0.23
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_PHONE  \
# ...

# %% [raw]
# # Encoding
#
# map_NAME_CONTRACT_TYPE = {'Cash loans':0,'Revolving loans':1}
# map_FLAG_OWN_CAR = {'N':0,'Y':1}
# map_FLAG_OWN_REALTY = {'N':0,'Y':1}
# map_CREDIT_ACTIVE = {'Bad debt':0,'Sold':1,'Closed':2,'Active':3}
# map_NAME_INCOME_TYPE = {'Unemployed':0,'Maternity leave':1,'Pensioner':2,'Student':3,
#                        'Working':4,'State servant':5,'Commercial associate':6,'Businessman':7}
# X_cat['NAME_CONTRACT_TYPE'] = X_cat['NAME_CONTRACT_TYPE'].map(map_NAME_CONTRACT_TYPE)
# X_cat['FLAG_OWN_CAR'] = X_cat['FLAG_OWN_CAR'].map(map_FLAG_OWN_CAR)
# X_cat['FLAG_OWN_REALTY'] = X_cat['FLAG_OWN_REALTY'].map(map_FLAG_OWN_REALTY)
# X_cat['CREDIT_ACTIVE'] = X_cat['CREDIT_ACTIVE'].map(map_CREDIT_ACTIVE)
# X_cat['NAME_INCOME_TYPE'] = X_cat['NAME_INCOME_TYPE'].map(map_NAME_INCOME_TYPE)

# %%
m = df_selected_features.columns
n = X_cat.columns
df_fit = df_join4[['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
       'AMT_GOODS_PRICE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'FLAG_EMP_PHONE',
       'FLAG_WORK_PHONE', 'FLAG_PHONE', 'CNT_FAM_MEMBERS',
       'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
       'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
       'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY',
       'LIVE_CITY_NOT_WORK_CITY', 'OBS_30_CNT_SOCIAL_CIRCLE',
       'OBS_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_2',
       'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_8',
       'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_13',
       'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16',
       'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_21',
       'AMT_DRAWINGS_POS_CURRENT', 'CNT_DRAWINGS_POS_CURRENT',
       'DAYS_INSTALMENT', 'DAYS_ENTRY_PAYMENT', 'AMT_INSTALMENT',
       'AMT_PAYMENT','NAME_CONTRACT_TYPE', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
       'NAME_INCOME_TYPE', 'CREDIT_ACTIVE','TARGET']]
df_fit.head()
# Out:
#    CNT_CHILDREN  AMT_INCOME_TOTAL   AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0        202,500.00   406,597.50    24,700.50       351,000.00
# 1             0        270,000.00 1,293,502.50    35,698.50     1,129,500.00
# 2             0         67,500.00   135,000.00     6,750.00       135,000.00
# 4             0        121,500.00   513,000.00    21,865.50       513,000.00
# 5             0         99,000.00   490,495.50    27,517.50       454,500.00
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0       -9461           -637               1                0           1
# 1      -16765          -1188               1                0           1
# 2      -19046           -225               1                1           1
# 4      -19932          -3038               1                0           0
# 5      -16941          -1588               1                1           1
#
# ...

# %%
# Simpan df_fit ke komputer, beri nama data_fit.csv
# data_fit digunakan untuk proses selanjutnya
# proses selanjutnya menggunakan file terpisah untuk menghindari memori overload

df_fit.to_csv('data_fit.csv', index=False)
